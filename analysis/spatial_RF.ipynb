# %%
#  Intepretation of the feature pooling field radius
import numpy as np
import matplotlib.pyplot as plt

# %%
f = 64
_w = np.load(f'../test_arrays/out_{f}/_w.npy')
_v = np.load(f'../test_arrays/out_{f}/_v.npy')

# %%
import os
os.makedirs(f'figure_pngs/spatial_RFs', exist_ok=True)

# %%
for i in range(0, 64):
    plt.imshow(_v[stim][i])
    plt.show()

# %%
stim = 35
for i, e in enumerate(range(0, 7)):
    # plt.subplot(7, 1, i+1)
    plt.figure(figsize=(4, 4))
    plt.imshow(_w[stim][e].mean(0), cmap = 'cubehelix')
    plt.axis('off')
    plt.figure(figsize=(4, 4))
    plt.imshow(_v[stim][e], cmap = 'cubehelix')
    plt.axis('off')

# %%
stim = 35

for i, e in enumerate(range(0, 7)):
    # plt.subplot(7, 1, i+1)
    plt.figure(figsize=(4, 4))
    plt.imshow(_w[stim][e].mean(0), cmap = 'cubehelix')
    plt.axis('off')
    plt.tight_layout(pad=0)  # Reduce padding to zero
    plt.savefig(f'figure_pngs/spatial_RFs/stim_{stim}_e{e}', bbox_inches='tight', pad_inches=0)  # Remove white space around the image
    # plt.close()
# plt.suptitle('V1')
    plt.show()

for i, e in enumerate(range(7, 11)):
    plt.figure(figsize=(4, 4))
    # plt.subplot(4, 1, i+1)
    plt.imshow(_w[stim][e].mean(0), cmap = 'cubehelix')
    plt.axis('off')
    plt.tight_layout(pad=0)  # Reduce padding to zero
    plt.savefig(f'figure_pngs/spatial_RFs/stim_{stim}_e{e}', bbox_inches='tight', pad_inches=0)  # Remove white space around the image
    plt.close()
# plt.suptitle('V4')
    # plt.show()

for i, e in enumerate(range(11, 15)):
    plt.figure(figsize=(4, 4))
    plt.imshow(_w[stim][e].mean(0), cmap = 'cubehelix')
    plt.axis('off')
    plt.tight_layout(pad=0)  # Reduce padding to zero
    plt.savefig(f'figure_pngs/spatial_RFs/stim_{stim}_e{e}', bbox_inches='tight', pad_inches=0)  # Remove white space around the image
    plt.close()
# plt.suptitle('IT')
    # plt.show()

# %%
# for stim in
plt.figure(figsize=(10,10))

for stim in range(100):
    plt.subplot(10,10,stim+1)
    plt.imshow(_w[stim].sum(0).sum(0), cmap='inferno')
    plt.axis('off')
    # plt.title(f'{stim}')
plt.show()

# %%
_w[stim].reshape(15, f, -1).sum(-1).shape
# Out:
# (15, 32)

# %%
_w[stim].shape
# Out:
# (15, 32, 64, 64)

# %%
plt.figure(figsize=(20,10))
for stim in range(100):
    plt.subplot(10,10,stim+1)
    plt.imshow(_w[stim].mean(0).mean(0), cmap='inferno')
    plt.axis('off')
    
    # plt.title(f'{stim}')
plt.show()

# %%
(15 * 64)
# Out:
# 960

# %%
64 * 64 * 15
# Out:
# 61440
